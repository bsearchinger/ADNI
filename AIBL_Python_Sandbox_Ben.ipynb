# %%
import pydicom
from pydicom import dcmread
data = dcmread('AIBL_10_PT_summed.img__RSRCH_RAMLA3D-SUV__br_raw_20090814103457930_38_S72352_I153055.dcm')
data
pix = data[0x7fe0, 0x0010]
pix.value

import matplotlib.pyplot as plt
plt.imshow(data.pixel_array)

# %%
import os

dir = r'C:\Users\Ben\Desktop\ADNI\AIBL\10\summed.img__RSRCH_RAMLA3D-SUV\2006-10-17_13_53_08.0\I153055'
for ds in os.scandir(dir):
    plt.imshow(dcmread(ds).pixel_array)
    plt.show(block = False)
