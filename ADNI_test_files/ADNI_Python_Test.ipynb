# %%
import os
import pydicom
from pydicom import dcmread
import matplotlib.pyplot as plt

dir = r'C:\Users\Ben\Desktop\ADNI\AIBL\10\summed.img__RSRCH_RAMLA3D-SUV\2006-10-17_13_53_08.0\I153055' # change this to repo loc
#for ds in os.scandir(dir):
#    plt.imshow(dcmread(ds).pixel_array)
#    plt.title(dcmread(ds).PatientID)
#    plt.show(block = False)
    
files = os.listdir(dir)
dat = dcmread(dir + '\\' + files[1])
dat
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 182
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Positron Emission Tomography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.16.124.113543.6006.99.4770756987297415684
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.16.124.113543.6006.99.1670620014862050651
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 400
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.124.113543.6006.99.4770756987297415684
# ...

# %%
import nibabel as nib
import os
import matplotlib.pyplot as plt

dir = r'C:\Users\Ben\Desktop\ADNI\ADNI_test_files'
img1 = nib.load(dir + '\\' + os.listdir(dir)[0])
img2 = nib.load(dir + '\\' + os.listdir(dir)[1])
img1_data = img1.get_fdata()
img2_data = img2.get_fdata()

def show_slices(slices):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices), figsize = (20, 10))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, origin="lower")
        
slice_0 = img1_data[26, :, :]
slice_1 = img1_data[:, 30, :]
slice_2 = img1_data[:, :, 16]

slice_3 = img2_data[26, :, :]
slice_4 = img2_data[:, 30, :]
slice_5 = img2_data[:, :, 16]
show_slices([slice_0, slice_1, slice_2, slice_3, slice_4, slice_5])

plt.savefig(r'C:\Users\Ben\Desktop\ADNI\ADNI_test_files\test.jpg')
