# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn as nil
from nilearn import plotting

# useful BASH command for moving files from ADNI download: find ADNI -type f -exec mv -t . {} +

# 30 AD patients and 30 CN patients; only other criteria considered is level of image processing
dir = ('./NII/')
files = os.listdir(dir)
plotting.plot_anat(dir + files[1])
#img = nib.load(dir + files[1])
#print(img.header)
